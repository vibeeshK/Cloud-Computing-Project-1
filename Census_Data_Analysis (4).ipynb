# %%
# first some initial setup of libraries we will be using
import pandas as pd # this is the main library used in python for manipulating data. 
import json # this is a library to parse json (javascript object notation)
from urllib.request import urlopen # library to read data from a URL
import matplotlib.pyplot as plt # visualization library we will use that integrates with pandas
import requests
from bs4 import BeautifulSoup 
import re
# !pip install plotly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: plotly in /usr/local/lib/python3.8/dist-packages (5.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from plotly) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from plotly) (8.1.0)

# %%
# We are reading in the data we want from ACS 2021. The API returns json data. Try copy and pasting the link yourself in a browser to see what the raw data looks like.
url="https://api.census.gov/data/2021/acs/acs1?get=NAME,B19001_001E,B19001_002E,B19001_017E&for=congressional%20district:*&in=state:*"

# store the response of URL
response = urlopen(url)

# storing the JSON response from url in data
data_json = json.loads(response.read())
data_json.pop(0) # the first row of data is header information which we don't need, so pop removes that from the dataset.

# Hand populate the columns based on the variable descriptions census.gov documents here: https://api.census.gov/data/2021/acs/acs1/variables.html. Note they correspond back to the variable names I included in the URL above.
cols = ['District Name','Total Households','Less than $10k', '$200k+', 'State code', 'district number']

acs_df = pd.DataFrame(data_json, columns = cols)

# time to do some basic cleanup of the data. We will need to extract the district number and state in a regular format so we can later join with the party data.
acs_df[['District', 'State']] = acs_df['District Name'].str.split(',', expand=True)
acs_df['district number'] = pd.to_numeric(acs_df['district number'])

acs_df['State'] = acs_df['State'].str.strip()

# Let's just keep the columns we need
acs_df = acs_df[['Total Households', 'Less than $10k', "$200k+", 'district number', 'State']]

# take a look at the top results in the dataset
acs_df.head()
# Out:
#   Total Households Less than $10k $200k+  district number        State
# 0           289474          14153  19390               10     Michigan
# 1           299804          23793  10899                4  Mississippi
# 2           278057          27728  19574               14     Michigan
# 3           306685          19036  12208                1     Michigan
# 4           285554          26481  12412                3  Mississippi

# %%
# Convert the number columns into number data types so we can math on them
acs_df["Total Households"] = pd.to_numeric(acs_df["Total Households"])
acs_df["Less than $10k"] = pd.to_numeric(acs_df["Less than $10k"])
acs_df['$200k+'] = pd.to_numeric(acs_df['$200k+'])

# Compute some new columns based on the existing columns for later visualization
acs_df['% of households over $200k'] = (100*acs_df['$200k+'])/acs_df['Total Households']
acs_df['% of households less than $10k'] = (100*acs_df['Less than $10k'])/acs_df['Total Households']

# now let's look at the data again
acs_df.head()
# Out:
#    Total Households  Less than $10k  $200k+  district number        State  \
# 0            289474           14153   19390               10     Michigan
# 1            299804           23793   10899                4  Mississippi
# 2            278057           27728   19574               14     Michigan
# 3            306685           19036   12208                1     Michigan
# 4            285554           26481   12412                3  Mississippi
#
#    % of households over $200k  % of households less than $10k
# 0                    6.698356                        4.889213
# 1                    3.635375                        7.936185
# 2                    7.039564                        9.972056
# 3                    3.980632                        6.207020
# 4                    4.346638                        9.273552

# %% [markdown]
# In order to find the number of metropolitan and micropolitan cities per state, we scrape data from www.citypopulation.de

# %%
url = "https://www.citypopulation.de/en/usa/metro/"
data = requests.get(url).text

soup = BeautifulSoup(data, 'html.parser')
tables = soup.find_all('td')
tables
# Out:
# [<td class="rname" data-area="7353.0041" data-density="5.7302" data-wd="Q4667022" data-wiki="Aberdeen, South Dakota micropolitan area" id="i10100"><a href="javascript:sym('10100')"><span itemprop="name">Aberdeen</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">SD</td>,
#  <td class="rpop prio5">39,936</td>,
#  <td class="rpop prio4">39,827</td>,
#  <td class="rpop prio3">40,602</td>,
#  <td class="rpop prio2">42,287</td>,
#  <td class="rpop prio1">42,134</td>,
#  <td class="sc"><a href="/en/usa/metro/10100__aberdeen/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="4924.7943" data-density="15.6029" data-wiki="Aberdeen, WA Micropolitan Statistical Area" id="i10140"><a href="javascript:sym('10140')"><span itemprop="name">Aberdeen</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">WA</td>,
#  <td class="rpop prio5">64,175</td>,
#  <td class="rpop prio4">67,194</td>,
#  <td class="rpop prio3">72,797</td>,
#  <td class="rpop prio2">75,636</td>,
#  <td class="rpop prio1">76,841</td>,
#  <td class="sc"><a href="/en/usa/metro/10140__aberdeen/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="7105.6683" data-density="24.9539" data-wd="Q4667785" data-wiki="Abilene, Texas metropolitan area" id="i10180"><a href="javascript:sym('10180')"><span itemprop="name">Abilene</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">TX</td>,
#  <td class="rpop prio5">148,004</td>,
#  <td class="rpop prio4">160,245</td>,
#  <td class="rpop prio3">165,252</td>,
#  <td class="rpop prio2">176,579</td>,
#  <td class="rpop prio1">177,314</td>,
#  <td class="sc"><a href="/en/usa/metro/10180__abilene/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1865.8563" data-density="20.4533" data-wiki="Ada, OK Micropolitan Statistical Area" id="i10220"><a href="javascript:sym('10220')"><span itemprop="name">Ada</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">OK</td>,
#  <td class="rpop prio5">34,119</td>,
#  <td class="rpop prio4">35,143</td>,
#  <td class="rpop prio3">37,492</td>,
#  <td class="rpop prio2">38,065</td>,
#  <td class="rpop prio1">38,163</td>,
#  <td class="sc"><a href="/en/usa/metro/10220__ada/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1941.5262" data-density="50.9682" data-wiki="Adrian, MI Micropolitan Statistical Area" id="i10300"><a href="javascript:sym('10300')"><span itemprop="name">Adrian</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">MI</td>,
#  <td class="rpop prio5">91,476</td>,
#  <td class="rpop prio4">98,890</td>,
#  <td class="rpop prio3">99,892</td>,
#  <td class="rpop prio2">99,423</td>,
#  <td class="rpop prio1">98,956</td>,
#  <td class="sc"><a href="/en/usa/metro/10300__adrian/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1222.4814" data-density="251.7732" data-wd="Q4694476" data-wiki="Aguadilla - Isabela metropolitan area" id="i10380"><a href="javascript:sym('10380')"><span itemprop="name">Aguadilla - Isabela</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">PR</td>,
#  <td class="rpop prio5">307,560</td>,
#  <td class="rpop prio4">347,938</td>,
#  <td class="rpop prio3">339,465</td>,
#  <td class="rpop prio2">310,160</td>,
#  <td class="rpop prio1">307,788</td>,
#  <td class="sc"><a href="/en/usa/metro/10380__aguadilla_isabela/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="2331.5022" data-density="300.242" data-wd="Q4701712" data-wiki="Akron, Ohio, metropolitan area" id="i10420"><a href="javascript:sym('10420')"><span itemprop="name">Akron</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">OH</td>,
#  <td class="rpop prio5">657,575</td>,
#  <td class="rpop prio4">694,960</td>,
#  <td class="rpop prio3">703,200</td>,
#  <td class="rpop prio2">702,219</td>,
#  <td class="rpop prio1">700,015</td>,
#  <td class="sc"><a href="/en/usa/metro/10420__akron/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="17126.456" data-density="4.0018" data-wiki="Alamogordo, NM Micropolitan Statistical Area" id="i10460"><a href="javascript:sym('10460')"><span itemprop="name">Alamogordo</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">NM</td>,
#  <td class="rpop prio5">51,928</td>,
#  <td class="rpop prio4">62,298</td>,
#  <td class="rpop prio3">63,797</td>,
#  <td class="rpop prio2">67,839</td>,
#  <td class="rpop prio1">68,537</td>,
#  <td class="sc"><a href="/en/usa/metro/10460__alamogordo/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="4120.748" data-density="35.8607" data-wd="Q4709271" data-wiki="Albany metropolitan area, Georgia" id="i10500"><a href="javascript:sym('10500')"><span itemprop="name">Albany</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">GA</td>,
#  <td class="rpop prio5">142,959</td>,
#  <td class="rpop prio4">153,759</td>,
#  <td class="rpop prio3">153,857</td>,
#  <td class="rpop prio2">148,922</td>,
#  <td class="rpop prio1">147,773</td>,
#  <td class="sc"><a href="/en/usa/metro/10500__albany/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="5929.1988" data-density="21.8982" data-wiki="Albany-Lebanon, OR Micropolitan Statistical Area" id="i10540"><a href="javascript:sym('10540')"><span itemprop="name">Albany - Lebanon</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">OR</td>,
#  <td class="rpop prio5">91,227</td>,
#  <td class="rpop prio4">103,069</td>,
#  <td class="rpop prio3">116,672</td>,
#  <td class="rpop prio2">128,610</td>,
#  <td class="rpop prio1">129,839</td>,
#  <td class="sc"><a href="/en/usa/metro/10540__albany_lebanon/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="7282.3798" data-density="123.4879" data-wd="Q3320597" data-wiki="Albany - Schenectady - Troy metropolitan area" id="i10580"><a href="javascript:sym('10580')"><span itemprop="name">Albany - Schenectady - Troy</span></a> (<span itemprop="name">Capital District</span>)</td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">NY</td>,
#  <td class="rpop prio5">809,443</td>,
#  <td class="rpop prio4">825,875</td>,
#  <td class="rpop prio3">870,716</td>,
#  <td class="rpop prio2">899,262</td>,
#  <td class="rpop prio1">899,286</td>,
#  <td class="sc"><a href="/en/usa/metro/10580__albany_schenectady_tr/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1023.25" data-density="61.9839" data-wiki="Albemarle, NC Micropolitan Statistical Area" id="i10620"><a href="javascript:sym('10620')"><span itemprop="name">Albemarle</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">NC</td>,
#  <td class="rpop prio5">51,765</td>,
#  <td class="rpop prio4">58,100</td>,
#  <td class="rpop prio3">60,585</td>,
#  <td class="rpop prio2">62,504</td>,
#  <td class="rpop prio1">63,425</td>,
#  <td class="sc"><a href="/en/usa/metro/10620__albemarle/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1831.7564" data-density="16.7866" data-wiki="Albert Lea, MN Micropolitan Statistical Area" id="i10660"><a href="javascript:sym('10660')"><span itemprop="name">Albert Lea</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">MN</td>,
#  <td class="rpop prio5">33,060</td>,
#  <td class="rpop prio4">32,584</td>,
#  <td class="rpop prio3">31,255</td>,
#  <td class="rpop prio2">30,895</td>,
#  <td class="rpop prio1">30,749</td>,
#  <td class="sc"><a href="/en/usa/metro/10660__albert_lea/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1465.5318" data-density="67.0255" data-wiki="Albertville, AL Micropolitan Statistical Area" id="i10700"><a href="javascript:sym('10700')"><span itemprop="name">Albertville</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">AL</td>,
#  <td class="rpop prio5">70,832</td>,
#  <td class="rpop prio4">82,231</td>,
#  <td class="rpop prio3">93,019</td>,
#  <td class="rpop prio2">97,612</td>,
#  <td class="rpop prio1">98,228</td>,
#  <td class="sc"><a href="/en/usa/metro/10700__albertville/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="24043.8853" data-density="38.191" data-wd="Q4712839" data-wiki="Albuquerque metropolitan area" id="i10740"><a href="javascript:sym('10740')"><span itemprop="name">Albuquerque</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">NM</td>,
#  <td class="rpop prio5">599,416</td>,
#  <td class="rpop prio4">729,649</td>,
#  <td class="rpop prio3">887,077</td>,
#  <td class="rpop prio2">916,528</td>,
#  <td class="rpop prio1">918,259</td>,
#  <td class="sc"><a href="/en/usa/metro/10740__albuquerque/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="3541.645" data-density="14.5336" data-wd="Q4718609" data-wiki="Alexander City micropolitan area" id="i10760"><a href="javascript:sym('10760')"><span itemprop="name">Alexander City</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">AL</td>,
#  <td class="rpop prio5">49,889</td>,
#  <td class="rpop prio4">53,677</td>,
#  <td class="rpop prio3">53,155</td>,
#  <td class="rpop prio2">51,698</td>,
#  <td class="rpop prio1">51,473</td>,
#  <td class="sc"><a href="/en/usa/metro/10760__alexander_city/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="5085.7053" data-density="29.6694" data-wd="Q4720927" data-wiki="Alexandria, Louisiana metropolitan area" id="i10780"><a href="javascript:sym('10780')"><span itemprop="name">Alexandria</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">LA</td>,
#  <td class="rpop prio5">149,082</td>,
#  <td class="rpop prio4">145,035</td>,
#  <td class="rpop prio3">153,922</td>,
#  <td class="rpop prio2">152,192</td>,
#  <td class="rpop prio1">150,890</td>,
#  <td class="sc"><a href="/en/usa/metro/10780__alexandria/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1649.6593" data-density="23.7855" data-wiki="Alexandria, MN Micropolitan Statistical Area" id="i10820"><a href="javascript:sym('10820')"><span itemprop="name">Alexandria</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">MN</td>,
#  <td class="rpop prio5">28,674</td>,
#  <td class="rpop prio4">32,821</td>,
#  <td class="rpop prio3">36,009</td>,
#  <td class="rpop prio2">39,006</td>,
#  <td class="rpop prio1">39,238</td>,
#  <td class="sc"><a href="/en/usa/metro/10820__alexandria/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="6885.88" data-density="7.0584" data-wiki="Alice, TX Micropolitan Statistical Area" id="i10860"><a href="javascript:sym('10860')"><span itemprop="name">Alice</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">TX</td>,
#  <td class="rpop prio5">50,597</td>,
#  <td class="rpop prio4">52,446</td>,
#  <td class="rpop prio3">52,620</td>,
#  <td class="rpop prio2">48,722</td>,
#  <td class="rpop prio1">48,603</td>,
#  <td class="sc"><a href="/en/usa/metro/10860__alice/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="3763.2112" data-density="229.9393" data-wd="Q123202" data-wiki="Allentown metropolitan area" id="i10900"><a href="javascript:sym('10900')"><span itemprop="name">Allentown - Bethlehem - Easton</span></a> (<span itemprop="name">Lehigh Valley</span>)</td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">PA-NJ</td>,
#  <td class="rpop prio5">686,688</td>,
#  <td class="rpop prio4">740,395</td>,
#  <td class="rpop prio3">821,173</td>,
#  <td class="rpop prio2">861,889</td>,
#  <td class="rpop prio1">865,310</td>,
#  <td class="sc"><a href="/en/usa/metro/10900__allentown_bethlehem_e/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1472.0989" data-density="28.2209" data-wiki="Alma, MI Micropolitan Statistical Area" id="i10940"><a href="javascript:sym('10940')"><span itemprop="name">Alma</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">MI</td>,
#  <td class="rpop prio5">38,982</td>,
#  <td class="rpop prio4">42,285</td>,
#  <td class="rpop prio3">42,476</td>,
#  <td class="rpop prio2">41,761</td>,
#  <td class="rpop prio1">41,544</td>,
#  <td class="sc"><a href="/en/usa/metro/10940__alma/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1481.2052" data-density="19.5064" data-wiki="Alpena, MI Micropolitan Statistical Area" id="i10980"><a href="javascript:sym('10980')"><span itemprop="name">Alpena</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">MI</td>,
#  <td class="rpop prio5">30,605</td>,
#  <td class="rpop prio4">31,314</td>,
#  <td class="rpop prio3">29,598</td>,
#  <td class="rpop prio2">28,907</td>,
#  <td class="rpop prio1">28,893</td>,
#  <td class="sc"><a href="/en/usa/metro/10980__alpena/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1360.4581" data-density="89.5044" data-wiki="Altoona, PA Metropolitan Statistical Area" id="i11020"><a href="javascript:sym('11020')"><span itemprop="name">Altoona</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">PA</td>,
#  <td class="rpop prio5">130,542</td>,
#  <td class="rpop prio4">129,144</td>,
#  <td class="rpop prio3">127,089</td>,
#  <td class="rpop prio2">122,822</td>,
#  <td class="rpop prio1">121,767</td>,
#  <td class="sc"><a href="/en/usa/metro/11020__altoona/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="2078.8605" data-density="11.9185" data-wiki="Altus, OK Micropolitan Statistical Area" id="i11060"><a href="javascript:sym('11060')"><span itemprop="name">Altus</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">OK</td>,
#  <td class="rpop prio5">28,764</td>,
#  <td class="rpop prio4">28,439</td>,
#  <td class="rpop prio3">26,446</td>,
#  <td class="rpop prio2">24,785</td>,
#  <td class="rpop prio1">24,777</td>,
#  <td class="sc"><a href="/en/usa/metro/11060__altus/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="13340.9799" data-density="20.2161" data-wd="Q4740293" data-wiki="Amarillo metropolitan area" id="i11100"><a href="javascript:sym('11100')"><span itemprop="name">Amarillo</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">TX</td>,
#  <td class="rpop prio5">198,422</td>,
#  <td class="rpop prio4">228,707</td>,
#  <td class="rpop prio3">251,933</td>,
#  <td class="rpop prio2">268,691</td>,
#  <td class="rpop prio1">269,703</td>,
#  <td class="sc"><a href="/en/usa/metro/11100__amarillo/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1682.9375" data-density="20.0608" data-wd="Q4745699" data-wiki="Americus micropolitan area" id="i11140"><a href="javascript:sym('11140')"><span itemprop="name">Americus</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">GA</td>,
#  <td class="rpop prio5">33,816</td>,
#  <td class="rpop prio4">36,966</td>,
#  <td class="rpop prio3">37,829</td>,
#  <td class="rpop prio2">34,163</td>,
#  <td class="rpop prio1">33,761</td>,
#  <td class="sc"><a href="/en/usa/metro/11140__americus/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="2960.4383" data-density="42.6271" data-wiki="Ames, IA Metropolitan Statistical Area" id="i11180"><a href="javascript:sym('11180')"><span itemprop="name">Ames</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">IA</td>,
#  <td class="rpop prio5">99,438</td>,
#  <td class="rpop prio4">106,205</td>,
#  <td class="rpop prio3">115,848</td>,
#  <td class="rpop prio2">125,252</td>,
#  <td class="rpop prio1">126,195</td>,
#  <td class="sc"><a href="/en/usa/metro/11180__ames/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1044.0514" data-density="47.467" data-wiki="Amsterdam, NY Micropolitan Statistical Area" id="i11220"><a href="javascript:sym('11220')"><span itemprop="name">Amsterdam</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">NY</td>,
#  <td class="rpop prio5">51,981</td>,
#  <td class="rpop prio4">49,708</td>,
#  <td class="rpop prio3">50,219</td>,
#  <td class="rpop prio2">49,532</td>,
#  <td class="rpop prio1">49,558</td>,
#  <td class="sc"><a href="/en/usa/metro/11220__amsterdam/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="68411.3385" data-density="5.8295" data-wd="Q4752744" data-wiki="Anchorage metropolitan area" id="i11260"><a href="javascript:sym('11260')"><span itemprop="name">Anchorage</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">AK</td>,
#  <td class="rpop prio5">266,021</td>,
#  <td class="rpop prio4">319,605</td>,
#  <td class="rpop prio3">380,821</td>,
#  <td class="rpop prio2">398,328</td>,
#  <td class="rpop prio1">398,807</td>,
#  <td class="sc"><a href="/en/usa/metro/11260__anchorage/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="3886.8503" data-density="4.7442" data-wiki="Andrews, TX Micropolitan Statistical Area" id="i11380"><a href="javascript:sym('11380')"><span itemprop="name">Andrews</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">TX</td>,
#  <td class="rpop prio5">14,338</td>,
#  <td class="rpop prio4">13,004</td>,
#  <td class="rpop prio3">14,786</td>,
#  <td class="rpop prio2">18,610</td>,
#  <td class="rpop prio1">18,440</td>,
#  <td class="sc"><a href="/en/usa/metro/11380__andrews/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="799.7292" data-density="43.3047" data-wiki="Angola, IN Micropolitan Statistical Area" id="i11420"><a href="javascript:sym('11420')"><span itemprop="name">Angola</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">IN</td>,
#  <td class="rpop prio5">27,446</td>,
#  <td class="rpop prio4">33,214</td>,
#  <td class="rpop prio3">34,185</td>,
#  <td class="rpop prio2">34,435</td>,
#  <td class="rpop prio1">34,632</td>,
#  <td class="sc"><a href="/en/usa/metro/11420__angola/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1828.5397" data-density="202.0137" data-wiki="Ann Arbor, MI Metropolitan Statistical Area" id="i11460"><a href="javascript:sym('11460')"><span itemprop="name">Ann Arbor</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">MI</td>,
#  <td class="rpop prio5">282,937</td>,
#  <td class="rpop prio4">322,895</td>,
#  <td class="rpop prio3">344,791</td>,
#  <td class="rpop prio2">372,258</td>,
#  <td class="rpop prio1">369,390</td>,
#  <td class="sc"><a href="/en/usa/metro/11460__ann_arbor/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1569.2461" data-density="73.903" data-wiki="Anniston-Oxford, AL Metropolitan Statistical Area" id="i11500"><a href="javascript:sym('11500')"><span itemprop="name">Anniston - Oxford</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">AL</td>,
#  <td class="rpop prio5">116,034</td>,
#  <td class="rpop prio4">112,249</td>,
#  <td class="rpop prio3">118,572</td>,
#  <td class="rpop prio2">116,441</td>,
#  <td class="rpop prio1">115,972</td>,
#  <td class="sc"><a href="/en/usa/metro/11500__anniston_oxford/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="2475.5295" data-density="98.5987" data-wiki="Appleton, WI Metropolitan Statistical Area" id="i11540"><a href="javascript:sym('11540')"><span itemprop="name">Appleton</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">WI</td>,
#  <td class="rpop prio5">174,801</td>,
#  <td class="rpop prio4">201,602</td>,
#  <td class="rpop prio3">225,666</td>,
#  <td class="rpop prio2">243,147</td>,
#  <td class="rpop prio1">244,084</td>,
#  <td class="sc"><a href="/en/usa/metro/11540__appleton/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1649.0318" data-density="20.8656" data-wiki="Arcadia, FL Micropolitan Statistical Area" id="i11580"><a href="javascript:sym('11580')"><span itemprop="name">Arcadia</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">FL</td>,
#  <td class="rpop prio5">23,865</td>,
#  <td class="rpop prio4">32,209</td>,
#  <td class="rpop prio3">34,862</td>,
#  <td class="rpop prio2">33,976</td>,
#  <td class="rpop prio1">34,408</td>,
#  <td class="sc"><a href="/en/usa/metro/11580__arcadia/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="3460.529" data-density="16.907" data-wd="Q4788210" data-wiki="Ardmore, Oklahoma micropolitan area" id="i11620"><a href="javascript:sym('11620')"><span itemprop="name">Ardmore</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">OK</td>,
#  <td class="rpop prio5">51,076</td>,
#  <td class="rpop prio4">54,452</td>,
#  <td class="rpop prio3">56,980</td>,
#  <td class="rpop prio2">58,149</td>,
#  <td class="rpop prio1">58,507</td>,
#  <td class="sc"><a href="/en/usa/metro/11620__ardmore/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="613.2181" data-density="296.8177" data-wiki="Arecibo metropolitan area" id="i11640"><a href="javascript:sym('11640')"><span itemprop="name">Arecibo</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">PR</td>,
#  <td class="rpop prio5">176,430</td>,
#  <td class="rpop prio4">199,750</td>,
#  <td class="rpop prio3">199,471</td>,
#  <td class="rpop prio2">182,705</td>,
#  <td class="rpop prio1">182,014</td>,
#  <td class="sc"><a href="/en/usa/metro/11640__arecibo/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="2242.8552" data-density="9.5062" data-wiki="Arkadelphia, AR Micropolitan Statistical Area" id="i11660"><a href="javascript:sym('11660')"><span itemprop="name">Arkadelphia</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">AR</td>,
#  <td class="rpop prio5">21,437</td>,
#  <td class="rpop prio4">23,546</td>,
#  <td class="rpop prio3">22,995</td>,
#  <td class="rpop prio2">21,446</td>,
#  <td class="rpop prio1">21,321</td>,
#  <td class="sc"><a href="/en/usa/metro/11660__arkadelphia/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="5264.4655" data-density="89.7225" data-wd="Q4804935" data-wiki="Asheville metropolitan area" id="i11700"><a href="javascript:sym('11700')"><span itemprop="name">Asheville</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">NC</td>,
#  <td class="rpop prio5">308,001</td>,
#  <td class="rpop prio4">369,171</td>,
#  <td class="rpop prio3">424,858</td>,
#  <td class="rpop prio2">469,015</td>,
#  <td class="rpop prio1">472,341</td>,
#  <td class="sc"><a href="/en/usa/metro/11700__asheville/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1095.5308" data-density="47.754" data-wiki="Ashland, OH Micropolitan Statistical Area" id="i11740"><a href="javascript:sym('11740')"><span itemprop="name">Ashland</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">OH</td>,
#  <td class="rpop prio5">47,507</td>,
#  <td class="rpop prio4">52,523</td>,
#  <td class="rpop prio3">53,139</td>,
#  <td class="rpop prio2">52,447</td>,
#  <td class="rpop prio1">52,316</td>,
#  <td class="sc"><a href="/en/usa/metro/11740__ashland/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1818.345" data-density="53.5305" data-wiki="Ashtabula, OH Micropolitan Statistical Area" id="i11780"><a href="javascript:sym('11780')"><span itemprop="name">Ashtabula</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">OH</td>,
#  <td class="rpop prio5">99,821</td>,
#  <td class="rpop prio4">102,728</td>,
#  <td class="rpop prio3">101,497</td>,
#  <td class="rpop prio2">97,574</td>,
#  <td class="rpop prio1">97,337</td>,
#  <td class="sc"><a href="/en/usa/metro/11780__ashtabula/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="2144.8467" data-density="19.4932" data-wiki="Astoria, OR Micropolitan Statistical Area" id="i11820"><a href="javascript:sym('11820')"><span itemprop="name">Astoria</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">OR</td>,
#  <td class="rpop prio5">33,301</td>,
#  <td class="rpop prio4">35,630</td>,
#  <td class="rpop prio3">37,039</td>,
#  <td class="rpop prio2">41,072</td>,
#  <td class="rpop prio1">41,810</td>,
#  <td class="sc"><a href="/en/usa/metro/11820__astoria/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1116.7366" data-density="14.5415" data-wiki="Atchison, KS Micropolitan Statistical Area" id="i11860"><a href="javascript:sym('11860')"><span itemprop="name">Atchison</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">KS</td>,
#  <td class="rpop prio5">16,932</td>,
#  <td class="rpop prio4">16,774</td>,
#  <td class="rpop prio3">16,924</td>,
#  <td class="rpop prio2">16,348</td>,
#  <td class="rpop prio1">16,239</td>,
#  <td class="sc"><a href="/en/usa/metro/11860__atchison/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1304.432" data-density="47.5732" data-wiki="Athens, OH Micropolitan Statistical Area" id="i11900"><a href="javascript:sym('11900')"><span itemprop="name">Athens</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">OH</td>,
#  <td class="rpop prio5">59,549</td>,
#  <td class="rpop prio4">62,223</td>,
#  <td class="rpop prio3">64,757</td>,
#  <td class="rpop prio2">62,431</td>,
#  <td class="rpop prio1">62,056</td>,
#  <td class="sc"><a href="/en/usa/metro/11900__athens/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1113.9973" data-density="48.527" data-wiki="Athens, TN Micropolitan Statistical Area" id="i11940"><a href="javascript:sym('11940')"><span itemprop="name">Athens</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">TN</td>,
#  <td class="rpop prio5">42,383</td>,
#  <td class="rpop prio4">49,015</td>,
#  <td class="rpop prio3">52,266</td>,
#  <td class="rpop prio2">53,276</td>,
#  <td class="rpop prio1">54,059</td>,
#  <td class="sc"><a href="/en/usa/metro/11940__athens/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="2263.0824" data-density="36.9704" data-wiki="Athens, TX Micropolitan Statistical Area" id="i11980"><a href="javascript:sym('11980')"><span itemprop="name">Athens</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">TX</td>,
#  <td class="rpop prio5">58,543</td>,
#  <td class="rpop prio4">73,277</td>,
#  <td class="rpop prio3">78,532</td>,
#  <td class="rpop prio2">82,150</td>,
#  <td class="rpop prio1">83,667</td>,
#  <td class="sc"><a href="/en/usa/metro/11980__athens/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="2654.6079" data-density="82.0306" data-wd="Q628450" data-wiki="Athens - Clarke County metropolitan area" id="i12020"><a href="javascript:sym('12020')"><span itemprop="name">Athens - Clarke County</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">GA</td>,
#  <td class="rpop prio5">136,025</td>,
#  <td class="rpop prio4">166,079</td>,
#  <td class="rpop prio3">192,541</td>,
#  <td class="rpop prio2">215,415</td>,
#  <td class="rpop prio1">217,759</td>,
#  <td class="sc"><a href="/en/usa/metro/12020__athens_clarke_county/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="22495.7806" data-density="273.1201" data-wd="Q971998" data-wiki="Atlanta metropolitan area" id="i12060"><a href="javascript:sym('12060')"><span itemprop="name">Atlanta - Sandy Springs - Alpharetta</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">GA</td>,
#  <td class="rpop prio5">3,082,308</td>,
#  <td class="rpop prio4">4,263,438</td>,
#  <td class="rpop prio3">5,286,728</td>,
#  <td class="rpop prio2">6,089,815</td>,
#  <td class="rpop prio1">6,144,050</td>,
#  <td class="sc"><a href="/en/usa/metro/12060__atlanta_sandy_springs_/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1438.7744" data-density="191.1113" data-wiki="Atlantic City-Hammonton, NJ Metropolitan Statistical Area" id="i12100"><a href="javascript:sym('12100')"><span itemprop="name">Atlantic City - Hammonton</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">NJ</td>,
#  <td class="rpop prio5">224,327</td>,
#  <td class="rpop prio4">252,552</td>,
#  <td class="rpop prio3">274,549</td>,
#  <td class="rpop prio2">274,534</td>,
#  <td class="rpop prio1">274,966</td>,
#  <td class="sc"><a href="/en/usa/metro/12100__atlantic_city_hammonton/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="2448.5952" data-density="14.9878" data-wiki="Atmore, AL Micropolitan Statistical Area" id="i12120"><a href="javascript:sym('12120')"><span itemprop="name">Atmore</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">AL</td>,
#  <td class="rpop prio5">35,518</td>,
#  <td class="rpop prio4">38,440</td>,
#  <td class="rpop prio3">38,319</td>,
#  <td class="rpop prio2">36,757</td>,
#  <td class="rpop prio1">36,699</td>,
#  <td class="sc"><a href="/en/usa/metro/12120__atmore/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="939.732" data-density="46.1121" data-wiki="Auburn, IN Micropolitan Statistical Area" id="i12140"><a href="javascript:sym('12140')"><span itemprop="name">Auburn</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">IN</td>,
#  <td class="rpop prio5">35,324</td>,
#  <td class="rpop prio4">40,285</td>,
#  <td class="rpop prio3">42,223</td>,
#  <td class="rpop prio2">43,265</td>,
#  <td class="rpop prio1">43,333</td>,
#  <td class="sc"><a href="/en/usa/metro/12140__auburn/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1791.1907" data-density="42.3629" data-wiki="Auburn, NY Micropolitan Statistical Area" id="i12180"><a href="javascript:sym('12180')"><span itemprop="name">Auburn</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">NY</td>,
#  <td class="rpop prio5">82,313</td>,
#  <td class="rpop prio4">81,963</td>,
#  <td class="rpop prio3">80,026</td>,
#  <td class="rpop prio2">76,248</td>,
#  <td class="rpop prio1">75,880</td>,
#  <td class="sc"><a href="/en/usa/metro/12180__auburn/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1573.5281" data-density="112.6246" data-wd="Q4819218" data-wiki="Auburn, Alabama, metropolitan area" id="i12220"><a href="javascript:sym('12220')"><span itemprop="name">Auburn - Opelika</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">AL</td>,
#  <td class="rpop prio5">87,146</td>,
#  <td class="rpop prio4">115,092</td>,
#  <td class="rpop prio3">140,247</td>,
#  <td class="rpop prio2">174,241</td>,
#  <td class="rpop prio1">177,218</td>,
#  <td class="sc"><a href="/en/usa/metro/12220__auburn_opelika/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="9015.0221" data-density="68.323" data-wd="Q4821005" data-wiki="Augusta metropolitan area" id="i12260"><a href="javascript:sym('12260')"><span itemprop="name">Augusta - Richmond County</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">GA-SC</td>,
#  <td class="rpop prio5">443,205</td>,
#  <td class="rpop prio4">508,032</td>,
#  <td class="rpop prio3">564,873</td>,
#  <td class="rpop prio2">611,000</td>,
#  <td class="rpop prio1">615,933</td>,
#  <td class="sc"><a href="/en/usa/metro/12260__augusta_richmond_county/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="2246.7396" data-density="55.4074" data-wiki="Augusta-Waterville, ME Micropolitan Statistical Area" id="i12300"><a href="javascript:sym('12300')"><span itemprop="name">Augusta - Waterville</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">ME</td>,
#  <td class="rpop prio5">115,904</td>,
#  <td class="rpop prio4">117,114</td>,
#  <td class="rpop prio3">122,151</td>,
#  <td class="rpop prio2">123,642</td>,
#  <td class="rpop prio1">124,486</td>,
#  <td class="sc"><a href="/en/usa/metro/12300__augusta_waterville/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1842.1879" data-density="21.7991" data-wiki="Austin, MN Micropolitan Statistical Area" id="i12380"><a href="javascript:sym('12380')"><span itemprop="name">Austin</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">MN</td>,
#  <td class="rpop prio5">37,385</td>,
#  <td class="rpop prio4">38,603</td>,
#  <td class="rpop prio3">39,163</td>,
#  <td class="rpop prio2">40,029</td>,
#  <td class="rpop prio1">40,158</td>,
#  <td class="sc"><a href="/en/usa/metro/12380__austin/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="10928.4653" data-density="215.2568" data-wd="Q5600444" data-wiki="Greater Austin" id="i12420"><a href="javascript:sym('12420')"><span itemprop="name">Austin - Round Rock - Georgetown</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">TX</td>,
#  <td class="rpop prio5">846,227</td>,
#  <td class="rpop prio4">1,249,763</td>,
#  <td class="rpop prio3">1,716,289</td>,
#  <td class="rpop prio2">2,283,371</td>,
#  <td class="rpop prio1">2,352,426</td>,
#  <td class="sc"><a href="/en/usa/metro/12420__austin_round_rock_geo/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1546.8428" data-density="18.7724" data-wiki="Bainbridge, GA Micropolitan Statistical Area" id="i12460"><a href="javascript:sym('12460')"><span itemprop="name">Bainbridge</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">GA</td>,
#  <td class="rpop prio5">25,511</td>,
#  <td class="rpop prio4">28,240</td>,
#  <td class="rpop prio3">27,842</td>,
#  <td class="rpop prio2">29,367</td>,
#  <td class="rpop prio1">29,038</td>,
#  <td class="sc"><a href="/en/usa/metro/12460__bainbridge/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="21068.6342" data-density="43.5564" data-wiki="Bakersfield, CA Metropolitan Statistical Area" id="i12540"><a href="javascript:sym('12540')"><span itemprop="name">Bakersfield</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">CA</td>,
#  <td class="rpop prio5">543,477</td>,
#  <td class="rpop prio4">661,645</td>,
#  <td class="rpop prio3">839,631</td>,
#  <td class="rpop prio2">909,235</td>,
#  <td class="rpop prio1">917,673</td>,
#  <td class="sc"><a href="/en/usa/metro/12540__bakersfield/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="6737.8803" data-density="421.2492" data-wd="Q4852987" data-wiki="Baltimore metropolitan area" id="i12580"><a href="javascript:sym('12580')"><span itemprop="name">Baltimore - Columbia - Towson</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">MD</td>,
#  <td class="rpop prio5">2,382,172</td>,
#  <td class="rpop prio4">2,552,994</td>,
#  <td class="rpop prio3">2,710,489</td>,
#  <td class="rpop prio2">2,844,510</td>,
#  <td class="rpop prio1">2,838,327</td>,
#  <td class="sc"><a href="/en/usa/metro/12580__baltimore_columbia_to/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="8798.6997" data-density="17.3622" data-wiki="Bangor, ME Metropolitan Statistical Area" id="i12620"><a href="javascript:sym('12620')"><span itemprop="name">Bangor</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">ME</td>,
#  <td class="rpop prio5">146,601</td>,
#  <td class="rpop prio4">144,919</td>,
#  <td class="rpop prio3">153,923</td>,
#  <td class="rpop prio2">152,199</td>,
#  <td class="rpop prio1">152,765</td>,
#  <td class="sc"><a href="/en/usa/metro/12620__bangor/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="2153.686" data-density="30.5044" data-wiki="Baraboo, WI Micropolitan Statistical Area" id="i12660"><a href="javascript:sym('12660')"><span itemprop="name">Baraboo</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">WI</td>,
#  <td class="rpop prio5">46,975</td>,
#  <td class="rpop prio4">55,225</td>,
#  <td class="rpop prio3">61,976</td>,
#  <td class="rpop prio2">65,763</td>,
#  <td class="rpop prio1">65,697</td>,
#  <td class="sc"><a href="/en/usa/metro/12660__baraboo/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1081.379" data-density="43.5536" data-wiki="Bardstown, KY Micropolitan Statistical Area" id="i12680"><a href="javascript:sym('12680')"><span itemprop="name">Bardstown</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">KY</td>,
#  <td class="rpop prio5">29,710</td>,
#  <td class="rpop prio4">37,477</td>,
#  <td class="rpop prio3">43,437</td>,
#  <td class="rpop prio2">46,738</td>,
#  <td class="rpop prio1">47,098</td>,
#  <td class="sc"><a href="/en/usa/metro/12680__bardstown/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1021.0282" data-density="227.6245" data-wiki="Barnstable Town, MA Metropolitan Statistical Area" id="i12700"><a href="javascript:sym('12700')"><span itemprop="name">Barnstable Town</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">MA</td>,
#  <td class="rpop prio5">186,605</td>,
#  <td class="rpop prio4">222,230</td>,
#  <td class="rpop prio3">215,888</td>,
#  <td class="rpop prio2">228,996</td>,
#  <td class="rpop prio1">232,411</td>,
#  <td class="sc"><a href="/en/usa/metro/12700__barnstable_town/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1778.2294" data-density="33.724" data-wiki="Barre, VT Micropolitan Statistical Area" id="i12740"><a href="javascript:sym('12740')"><span itemprop="name">Barre</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">VT</td>,
#  <td class="rpop prio5">54,928</td>,
#  <td class="rpop prio4">58,039</td>,
#  <td class="rpop prio3">59,534</td>,
#  <td class="rpop prio2">59,807</td>,
#  <td class="rpop prio1">59,969</td>,
#  <td class="sc"><a href="/en/usa/metro/12740__barre/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1076.2015" data-density="49.0354" data-wiki="Bartlesville, OK Micropolitan Statistical Area" id="i12780"><a href="javascript:sym('12780')"><span itemprop="name">Bartlesville</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">OK</td>,
#  <td class="rpop prio5">48,066</td>,
#  <td class="rpop prio4">48,996</td>,
#  <td class="rpop prio3">50,976</td>,
#  <td class="rpop prio2">52,455</td>,
#  <td class="rpop prio1">52,772</td>,
#  <td class="sc"><a href="/en/usa/metro/12780__bartlesville/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1276.7056" data-density="45.3143" data-wiki="Batavia, NY Micropolitan Statistical Area" id="i12860"><a href="javascript:sym('12860')"><span itemprop="name">Batavia</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">NY</td>,
#  <td class="rpop prio5">60,060</td>,
#  <td class="rpop prio4">60,370</td>,
#  <td class="rpop prio3">60,079</td>,
#  <td class="rpop prio2">58,388</td>,
#  <td class="rpop prio1">57,853</td>,
#  <td class="sc"><a href="/en/usa/metro/12860__batavia/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="3543.9736" data-density="15.6167" data-wiki="Batesville, AR Micropolitan Statistical Area" id="i12900"><a href="javascript:sym('12900')"><span itemprop="name">Batesville</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">AR</td>,
#  <td class="rpop prio5">45,301</td>,
#  <td class="rpop prio4">51,352</td>,
#  <td class="rpop prio3">53,911</td>,
#  <td class="rpop prio2">55,209</td>,
#  <td class="rpop prio1">55,345</td>,
#  <td class="sc"><a href="/en/usa/metro/12900__batesville/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="11320.0501" data-density="77.0231" data-wd="Q4869488" data-wiki="Baton Rouge metropolitan area" id="i12940"><a href="javascript:sym('12940')"><span itemprop="name">Baton Rouge</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">LA</td>,
#  <td class="rpop prio5">646,606</td>,
#  <td class="rpop prio4">729,361</td>,
#  <td class="rpop prio3">825,905</td>,
#  <td class="rpop prio2">870,569</td>,
#  <td class="rpop prio1">871,905</td>,
#  <td class="sc"><a href="/en/usa/metro/12940__baton_rouge/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1829.2102" data-density="73.1567" data-wiki="Battle Creek, MI Metropolitan Statistical Area" id="i12980"><a href="javascript:sym('12980')"><span itemprop="name">Battle Creek</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">MI</td>,
#  <td class="rpop prio5">135,982</td>,
#  <td class="rpop prio4">137,985</td>,
#  <td class="rpop prio3">136,146</td>,
#  <td class="rpop prio2">134,310</td>,
#  <td class="rpop prio1">133,819</td>,
#  <td class="sc"><a href="/en/usa/metro/12980__battle_creek/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1145.8303" data-density="89.8781" data-wiki="Bay City, MI Metropolitan Statistical Area" id="i13020"><a href="javascript:sym('13020')"><span itemprop="name">Bay City</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">MI</td>,
#  <td class="rpop prio5">111,723</td>,
#  <td class="rpop prio4">110,157</td>,
#  <td class="rpop prio3">107,771</td>,
#  <td class="rpop prio2">103,856</td>,
#  <td class="rpop prio1">102,985</td>,
#  <td class="sc"><a href="/en/usa/metro/13020__bay_city/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="2830.6454" data-density="12.8395" data-wiki="Bay City, TX Micropolitan Statistical Area" id="i13060"><a href="javascript:sym('13060')"><span itemprop="name">Bay City</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">TX</td>,
#  <td class="rpop prio5">36,928</td>,
#  <td class="rpop prio4">37,957</td>,
#  <td class="rpop prio3">36,702</td>,
#  <td class="rpop prio2">36,255</td>,
#  <td class="rpop prio1">36,344</td>,
#  <td class="sc"><a href="/en/usa/metro/13060__bay_city/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="2205.2738" data-density="9.802" data-wiki="Beatrice, NE Micropolitan Statistical Area" id="i13100"><a href="javascript:sym('13100')"><span itemprop="name">Beatrice</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">NE</td>,
#  <td class="rpop prio5">22,794</td>,
#  <td class="rpop prio4">22,993</td>,
#  <td class="rpop prio3">22,311</td>,
#  <td class="rpop prio2">21,704</td>,
#  <td class="rpop prio1">21,616</td>,
#  <td class="sc"><a href="/en/usa/metro/13100__beatrice/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="5441.9155" data-density="72.6617" data-wd="Q199187" data-wiki="Beaumont - Port Arthur metropolitan area" id="i13140"><a href="javascript:sym('13140')"><span itemprop="name">Beaumont - Port Arthur</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">TX</td>,
#  <td class="rpop prio5">361,226</td>,
#  <td class="rpop prio4">385,090</td>,
#  <td class="rpop prio3">388,745</td>,
#  <td class="rpop prio2">397,565</td>,
#  <td class="rpop prio1">395,419</td>,
#  <td class="sc"><a href="/en/usa/metro/13140__beaumont_port_arthur/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="2268.0497" data-density="39.3788" data-wiki="Beaver Dam, WI Micropolitan Statistical Area" id="i13180"><a href="javascript:sym('13180')"><span itemprop="name">Beaver Dam</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">WI</td>,
#  <td class="rpop prio5">76,559</td>,
#  <td class="rpop prio4">85,897</td>,
#  <td class="rpop prio3">88,759</td>,
#  <td class="rpop prio2">89,396</td>,
#  <td class="rpop prio1">89,313</td>,
#  <td class="sc"><a href="/en/usa/metro/13180__beaver_dam/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="3281.4414" data-density="34.6488" data-wiki="Beckley, WV Metropolitan Statistical Area" id="i13220"><a href="javascript:sym('13220')"><span itemprop="name">Beckley</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">WV</td>,
#  <td class="rpop prio5">124,771</td>,
#  <td class="rpop prio4">126,799</td>,
#  <td class="rpop prio3">124,898</td>,
#  <td class="rpop prio2">115,079</td>,
#  <td class="rpop prio1">113,698</td>,
#  <td class="sc"><a href="/en/usa/metro/13220__beckley/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1163.2825" data-density="38.7438" data-wiki="Bedford, IN Micropolitan Statistical Area" id="i13260"><a href="javascript:sym('13260')"><span itemprop="name">Bedford</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">IN</td>,
#  <td class="rpop prio5">42,836</td>,
#  <td class="rpop prio4">45,922</td>,
#  <td class="rpop prio3">46,134</td>,
#  <td class="rpop prio2">45,011</td>,
#  <td class="rpop prio1">45,070</td>,
#  <td class="sc"><a href="/en/usa/metro/13260__bedford/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="2279.8095" data-density="13.5643" data-wiki="Beeville, TX Micropolitan Statistical Area" id="i13300"><a href="javascript:sym('13300')"><span itemprop="name">Beeville</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">TX</td>,
#  <td class="rpop prio5">25,135</td>,
#  <td class="rpop prio4">32,359</td>,
#  <td class="rpop prio3">31,861</td>,
#  <td class="rpop prio2">31,047</td>,
#  <td class="rpop prio1">30,924</td>,
#  <td class="sc"><a href="/en/usa/metro/13300__beeville/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1187.5239" data-density="38.7655" data-wiki="Bellefontaine, OH Micropolitan Statistical Area" id="i13340"><a href="javascript:sym('13340')"><span itemprop="name">Bellefontaine</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">OH</td>,
#  <td class="rpop prio5">42,310</td>,
#  <td class="rpop prio4">46,005</td>,
#  <td class="rpop prio3">45,858</td>,
#  <td class="rpop prio2">46,150</td>,
#  <td class="rpop prio1">46,035</td>,
#  <td class="sc"><a href="/en/usa/metro/13340__bellefontaine/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="5459.4835" data-density="41.9144" data-wiki="Bellingham, WA Metropolitan Statistical Area" id="i13380"><a href="javascript:sym('13380')"><span itemprop="name">Bellingham</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">WA</td>,
#  <td class="rpop prio5">127,780</td>,
#  <td class="rpop prio4">166,814</td>,
#  <td class="rpop prio3">201,140</td>,
#  <td class="rpop prio2">226,847</td>,
#  <td class="rpop prio1">228,831</td>,
#  <td class="sc"><a href="/en/usa/metro/13380__bellingham/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="6487.1545" data-density="7.1495" data-wiki="Bemidji, MN Micropolitan Statistical Area" id="i13420"><a href="javascript:sym('13420')"><span itemprop="name">Bemidji</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">MN</td>,
#  <td class="rpop prio5">34,384</td>,
#  <td class="rpop prio4">39,650</td>,
#  <td class="rpop prio3">44,442</td>,
#  <td class="rpop prio2">46,228</td>,
#  <td class="rpop prio1">46,380</td>,
#  <td class="sc"><a href="/en/usa/metro/13420__bemidji/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="7815.5932" data-density="26.2042" data-wiki="Bend, OR Metropolitan Statistical Area" id="i13460"><a href="javascript:sym('13460')"><span itemprop="name">Bend</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">OR</td>,
#  <td class="rpop prio5">74,958</td>,
#  <td class="rpop prio4">115,367</td>,
#  <td class="rpop prio3">157,733</td>,
#  <td class="rpop prio2">198,253</td>,
#  <td class="rpop prio1">204,801</td>,
#  <td class="sc"><a href="/en/usa/metro/13460__bend/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1242.8673" data-density="21.2267" data-wiki="Bennettsville, SC Micropolitan Statistical Area" id="i13500"><a href="javascript:sym('13500')"><span itemprop="name">Bennettsville</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">SC</td>,
#  <td class="rpop prio5">29,361</td>,
#  <td class="rpop prio4">28,818</td>,
#  <td class="rpop prio3">28,933</td>,
#  <td class="rpop prio2">26,667</td>,
#  <td class="rpop prio1">26,382</td>,
#  <td class="sc"><a href="/en/usa/metro/13500__bennettsville/" itemprop="url">→</a></td>,
# ...
#  <td class="rpop prio1">37,312</td>,
#  <td class="sc"><a href="/en/usa/metro/13540__bennington/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="4647.9231" data-density="6.7318" data-wd="Q4892497" data-wiki="Berlin, New Hampshire micropolitan area" id="i13620"><a href="javascript:sym('13620')"><span itemprop="name">Berlin</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">NH</td>,
#  <td class="rpop prio5">34,828</td>,
#  <td class="rpop prio4">33,111</td>,
#  <td class="rpop prio3">33,055</td>,
#  <td class="rpop prio2">31,268</td>,
#  <td class="rpop prio1">31,289</td>,
#  <td class="sc"><a href="/en/usa/metro/13620__berlin/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1437.8436" data-density="27.841" data-wiki="Big Rapids, MI Micropolitan Statistical Area" id="i13660"><a href="javascript:sym('13660')"><span itemprop="name">Big Rapids</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">MI</td>,
#  <td class="rpop prio5">37,308</td>,
#  <td class="rpop prio4">40,553</td>,
#  <td class="rpop prio3">42,798</td>,
#  <td class="rpop prio2">39,714</td>,
#  <td class="rpop prio1">40,031</td>,
#  <td class="sc"><a href="/en/usa/metro/13660__big_rapids/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="2333.0391" data-density="14.6281" data-wiki="Big Spring, TX Micropolitan Statistical Area" id="i13700"><a href="javascript:sym('13700')"><span itemprop="name">Big Spring</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">TX</td>,
#  <td class="rpop prio5">32,343</td>,
#  <td class="rpop prio4">33,627</td>,
#  <td class="rpop prio3">35,012</td>,
#  <td class="rpop prio2">34,860</td>,
#  <td class="rpop prio1">34,128</td>,
#  <td class="sc"><a href="/en/usa/metro/13700__big_spring/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1064.2717" data-density="36.9389" data-wiki="Big Stone Gap, VA Micropolitan Statistical Area" id="i13720"><a href="javascript:sym('13720')"><span itemprop="name">Big Stone Gap</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">VA</td>,
#  <td class="rpop prio5">43,820</td>,
#  <td class="rpop prio4">44,027</td>,
#  <td class="rpop prio3">45,410</td>,
#  <td class="rpop prio2">39,817</td>,
#  <td class="rpop prio1">39,313</td>,
#  <td class="sc"><a href="/en/usa/metro/13720__big_stone_gap/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="16777.9302" data-density="11.1478" data-wd="Q11705538" data-wiki="Billings metropolitan area" id="i13740"><a href="javascript:sym('13740')"><span itemprop="name">Billings</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">MT</td>,
#  <td class="rpop prio5">128,035</td>,
#  <td class="rpop prio4">147,099</td>,
#  <td class="rpop prio3">167,167</td>,
#  <td class="rpop prio2">184,167</td>,
#  <td class="rpop prio1">187,037</td>,
#  <td class="sc"><a href="/en/usa/metro/13740__billings/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="3171.1948" data-density="77.3273" data-wd="Q4914264" data-wiki="Binghamton metropolitan area" id="i13780"><a href="javascript:sym('13780')"><span itemprop="name">Binghamton</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">NY</td>,
#  <td class="rpop prio5">264,497</td>,
#  <td class="rpop prio4">252,320</td>,
#  <td class="rpop prio3">251,725</td>,
#  <td class="rpop prio2">247,138</td>,
#  <td class="rpop prio1">245,220</td>,
#  <td class="sc"><a href="/en/usa/metro/13780__binghamton/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="11625.7777" data-density="95.8441" data-wd="Q4916875" data-wiki="Birmingham metropolitan area, Alabama" id="i13820"><a href="javascript:sym('13820')"><span itemprop="name">Birmingham - Hoover</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">AL</td>,
#  <td class="rpop prio5">889,174</td>,
#  <td class="rpop prio4">981,525</td>,
#  <td class="rpop prio3">1,061,024</td>,
#  <td class="rpop prio2">1,115,289</td>,
#  <td class="rpop prio1">1,114,262</td>,
#  <td class="sc"><a href="/en/usa/metro/13820__birmingham_hoover/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="11087.7028" data-density="12.1231" data-wd="Q2882032" data-wiki="Bismarck metropolitan area" id="i13900"><a href="javascript:sym('13900')"><span itemprop="name">Bismarck</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">ND</td>,
#  <td class="rpop prio5">86,212</td>,
#  <td class="rpop prio4">96,784</td>,
#  <td class="rpop prio3">110,625</td>,
#  <td class="rpop prio2">133,626</td>,
#  <td class="rpop prio1">134,417</td>,
#  <td class="sc"><a href="/en/usa/metro/13900__bismarck/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="5422.742" data-density="9.0132" data-wiki="Blackfoot, ID Micropolitan Statistical Area" id="i13940"><a href="javascript:sym('13940')"><span itemprop="name">Blackfoot</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">ID</td>,
#  <td class="rpop prio5">37,583</td>,
#  <td class="rpop prio4">41,735</td>,
#  <td class="rpop prio3">45,607</td>,
#  <td class="rpop prio2">47,992</td>,
#  <td class="rpop prio1">48,876</td>,
#  <td class="sc"><a href="/en/usa/metro/13940__blackfoot/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="2780.5769" data-density="59.4456" data-wd="Q4923347" data-wiki="Blacksburg - Christiansburg metropolitan area" id="i13980"><a href="javascript:sym('13980')"><span itemprop="name">Blacksburg - Christiansburg</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">VA</td>,
#  <td class="rpop prio5">140,715</td>,
#  <td class="rpop prio4">151,272</td>,
#  <td class="rpop prio3">162,958</td>,
#  <td class="rpop prio2">166,378</td>,
#  <td class="rpop prio1">165,293</td>,
#  <td class="sc"><a href="/en/usa/metro/13980__blacksburg_christiansbu/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="3064.5973" data-density="55.7623" data-wd="Q2907050" data-wiki="Bloomington metropolitan area" id="i14010"><a href="javascript:sym('14010')"><span itemprop="name">Bloomington</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">IL</td>,
#  <td class="rpop prio5">129,180</td>,
#  <td class="rpop prio4">150,433</td>,
#  <td class="rpop prio3">169,572</td>,
#  <td class="rpop prio2">170,954</td>,
#  <td class="rpop prio1">170,889</td>,
#  <td class="sc"><a href="/en/usa/metro/14010__bloomington/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="2019.716" data-density="79.8731" data-wd="Q4928327" data-wiki="Bloomington metropolitan area, Indiana" id="i14020"><a href="javascript:sym('14020')"><span itemprop="name">Bloomington</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">IN</td>,
#  <td class="rpop prio5">126,259</td>,
#  <td class="rpop prio4">142,349</td>,
#  <td class="rpop prio3">159,549</td>,
#  <td class="rpop prio2">161,039</td>,
#  <td class="rpop prio1">161,321</td>,
#  <td class="sc"><a href="/en/usa/metro/14020__bloomington/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1588.8346" data-density="52.2137" data-wd="Q260882" data-wiki="Bloomsburg - Berwick metropolitan area" id="i14100"><a href="javascript:sym('14100')"><span itemprop="name">Bloomsburg - Berwick</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">PA</td>,
#  <td class="rpop prio5">80,937</td>,
#  <td class="rpop prio4">82,387</td>,
#  <td class="rpop prio3">85,562</td>,
#  <td class="rpop prio2">82,863</td>,
#  <td class="rpop prio1">82,959</td>,
#  <td class="sc"><a href="/en/usa/metro/14100__bloomsburg_berwick/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="3355.0803" data-density="31.3539" data-wd="Q4930305" data-wiki="Bluefield micropolitan area" id="i14140"><a href="javascript:sym('14140')"><span itemprop="name">Bluefield</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">WV-VA</td>,
#  <td class="rpop prio5">117,454</td>,
#  <td class="rpop prio4">114,449</td>,
#  <td class="rpop prio3">114,166</td>,
#  <td class="rpop prio2">106,363</td>,
#  <td class="rpop prio1">105,195</td>,
#  <td class="sc"><a href="/en/usa/metro/14140__bluefield/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="953.3413" data-density="29.577" data-wiki="Bluffton, Indiana micropolitan area" id="i14160"><a href="javascript:sym('14160')"><span itemprop="name">Bluffton</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">IN</td>,
#  <td class="rpop prio5">25,948</td>,
#  <td class="rpop prio4">27,600</td>,
#  <td class="rpop prio3">27,636</td>,
#  <td class="rpop prio2">28,180</td>,
#  <td class="rpop prio1">28,197</td>,
#  <td class="sc"><a href="/en/usa/metro/14160__bluffton/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="2336.4099" data-density="16.9752" data-wiki="Blytheville, AR Micropolitan Statistical Area" id="i14180"><a href="javascript:sym('14180')"><span itemprop="name">Blytheville</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">AR</td>,
#  <td class="rpop prio5">57,525</td>,
#  <td class="rpop prio4">51,979</td>,
#  <td class="rpop prio3">46,480</td>,
#  <td class="rpop prio2">40,685</td>,
#  <td class="rpop prio1">39,661</td>,
#  <td class="sc"><a href="/en/usa/metro/14180__blytheville/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1734.3521" data-density="26.023" data-wiki="Bogalusa, LA Micropolitan Statistical Area" id="i14220"><a href="javascript:sym('14220')"><span itemprop="name">Bogalusa</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">LA</td>,
#  <td class="rpop prio5">43,185</td>,
#  <td class="rpop prio4">43,926</td>,
#  <td class="rpop prio3">47,168</td>,
#  <td class="rpop prio2">45,463</td>,
#  <td class="rpop prio1">45,133</td>,
#  <td class="sc"><a href="/en/usa/metro/14220__bogalusa/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="30475.3369" data-density="26.0955" data-wd="Q4938481" data-wiki="Boise metropolitan area" id="i14260"><a href="javascript:sym('14260')"><span itemprop="name">Boise City</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">ID</td>,
#  <td class="rpop prio5">319,596</td>,
#  <td class="rpop prio4">464,840</td>,
#  <td class="rpop prio3">616,561</td>,
#  <td class="rpop prio2">764,718</td>,
#  <td class="rpop prio1">795,268</td>,
#  <td class="sc"><a href="/en/usa/metro/14260__boise_city/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="2307.2511" data-density="15.8496" data-wiki="Bonham, TX Micropolitan Statistical Area" id="i14300"><a href="javascript:sym('14300')"><span itemprop="name">Bonham</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">TX</td>,
#  <td class="rpop prio5">24,804</td>,
#  <td class="rpop prio4">31,242</td>,
#  <td class="rpop prio3">33,915</td>,
#  <td class="rpop prio2">35,662</td>,
#  <td class="rpop prio1">36,569</td>,
#  <td class="sc"><a href="/en/usa/metro/14300__bonham/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="809.211" data-density="67.0208" data-wiki="Boone, NC Micropolitan Statistical Area" id="i14380"><a href="javascript:sym('14380')"><span itemprop="name">Boone</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">NC</td>,
#  <td class="rpop prio5">36,952</td>,
#  <td class="rpop prio4">42,695</td>,
#  <td class="rpop prio3">51,079</td>,
#  <td class="rpop prio2">54,086</td>,
#  <td class="rpop prio1">54,234</td>,
#  <td class="sc"><a href="/en/usa/metro/14380__boone/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="2298.4082" data-density="8.917" data-wiki="Borger, TX Micropolitan Statistical Area" id="i14420"><a href="javascript:sym('14420')"><span itemprop="name">Borger</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">TX</td>,
#  <td class="rpop prio5">25,689</td>,
#  <td class="rpop prio4">23,857</td>,
#  <td class="rpop prio3">22,150</td>,
#  <td class="rpop prio2">20,617</td>,
#  <td class="rpop prio1">20,495</td>,
#  <td class="sc"><a href="/en/usa/metro/14420__borger/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="9028.9597" data-density="542.6906" data-wd="Q1190137" data-wiki="Boston metropolitan area" id="i14460"><a href="javascript:sym('14460')"><span itemprop="name">Boston - Cambridge - Newton</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">MA-NH</td>,
#  <td class="rpop prio5">4,133,895</td>,
#  <td class="rpop prio4">4,391,344</td>,
#  <td class="rpop prio3">4,552,402</td>,
#  <td class="rpop prio2">4,941,632</td>,
#  <td class="rpop prio1">4,899,932</td>,
#  <td class="sc"><a href="/en/usa/metro/14460__boston_cambridge_newt/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1881.3241" data-density="175.1655" data-wiki="Boulder, CO Metropolitan Statistical Area" id="i14500"><a href="javascript:sym('14500')"><span itemprop="name">Boulder</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">CO</td>,
#  <td class="rpop prio5">209,050</td>,
#  <td class="rpop prio4">269,755</td>,
#  <td class="rpop prio3">294,567</td>,
#  <td class="rpop prio2">330,758</td>,
#  <td class="rpop prio1">329,543</td>,
#  <td class="sc"><a href="/en/usa/metro/14500__boulder/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="4182.9185" data-density="43.6523" data-wd="Q4951176" data-wiki="Bowling Green, Kentucky metropolitan area" id="i14540"><a href="javascript:sym('14540')"><span itemprop="name">Bowling Green</span></a></td>,
#  <td class="rstatus">Metropolitan Statistical Area</td>,
#  <td class="radm">KY</td>,
#  <td class="rpop prio5">112,903</td>,
#  <td class="rpop prio4">134,976</td>,
#  <td class="rpop prio3">158,599</td>,
#  <td class="rpop prio2">179,639</td>,
#  <td class="rpop prio1">182,594</td>,
#  <td class="sc"><a href="/en/usa/metro/14540__bowling_green/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="6747.831" data-density="18.1855" data-wiki="Bozeman, MT Micropolitan Statistical Area" id="i14580"><a href="javascript:sym('14580')"><span itemprop="name">Bozeman</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">MT</td>,
#  <td class="rpop prio5">50,463</td>,
#  <td class="rpop prio4">67,831</td>,
#  <td class="rpop prio3">89,513</td>,
#  <td class="rpop prio2">118,960</td>,
#  <td class="rpop prio1">122,713</td>,
#  <td class="sc"><a href="/en/usa/metro/14580__bozeman/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="2537.3959" data-density="15.7409" data-wiki="Bradford, PA Micropolitan Statistical Area" id="i14620"><a href="javascript:sym('14620')"><span itemprop="name">Bradford</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">PA</td>,
#  <td class="rpop prio5">47,131</td>,
#  <td class="rpop prio4">45,936</td>,
#  <td class="rpop prio3">43,450</td>,
#  <td class="rpop prio2">40,432</td>,
#  <td class="rpop prio1">39,941</td>,
#  <td class="sc"><a href="/en/usa/metro/14620__bradford/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="7821.3241" data-density="12.5182" data-wd="Q4955886" data-wiki="Brainerd, Minnesota micropolitan area" id="i14660"><a href="javascript:sym('14660')"><span itemprop="name">Brainerd</span></a></td>,
#  <td class="rstatus">Micropolitan Statistical Area</td>,
#  <td class="radm">MN</td>,
#  <td class="rpop prio5">66,040</td>,
#  <td class="rpop prio4">82,249</td>,
#  <td class="rpop prio3">91,067</td>,
#  <td class="rpop prio2">96,189</td>,
#  <td class="rpop prio1">97,909</td>,
#  <td class="sc"><a href="/en/usa/metro/14660__brainerd/" itemprop="url">→</a></td>,
#  <td class="rname" data-area="1637.7312" data-density="34.4299" data-wd="Q4957564" data-wiki="Branson, Missouri micropolitan area" id="i14700"><a href="javascript:sym('14700')"><span itemprop="name">Branson</span></a></td>,
#  ...]

# %%
# Create function to remove html from the extracted strings
CLEANR = re.compile('<.*?>') 
def cleanhtml(raw_html):
  cleantext = re.sub(CLEANR, '', raw_html)
  return cleantext

cleanhtml(str(tables[1]))
clean_values = []
for i in tables:
  clean_values.append(cleanhtml(str(i)))
clean_values[0:20]
# Out:
# ['Aberdeen',
#  'Micropolitan Statistical Area',
#  'SD',
#  '39,936',
#  '39,827',
#  '40,602',
#  '42,287',
#  '42,134',
#  '→',
#  'Aberdeen',
#  'Micropolitan Statistical Area',
#  'WA',
#  '64,175',
#  '67,194',
#  '72,797',
#  '75,636',
#  '76,841',
#  '→',
#  'Abilene',
#  'Metropolitan Statistical Area']

# %%
# Remove all the arrows in the list
ele='→'
clean_values=[i for i in clean_values if i!=ele]
clean_values[0:20]
# Out:
# ['Aberdeen',
#  'Micropolitan Statistical Area',
#  'SD',
#  '39,936',
#  '39,827',
#  '40,602',
#  '42,287',
#  '42,134',
#  'Aberdeen',
#  'Micropolitan Statistical Area',
#  'WA',
#  '64,175',
#  '67,194',
#  '72,797',
#  '75,636',
#  '76,841',
#  'Abilene',
#  'Metropolitan Statistical Area',
#  'TX',
#  '148,004']

# %%
# Convert the list of values into a dataframe

df = [] 
rows = [] 
for i in clean_values:
  if len(rows)!=7:
    rows.append(i)
  else:
    df.append(rows)
    rows = []
df2 = pd.DataFrame(df, columns = ['City', 'Status','State','2000','2010','2020','2021'])  
df2.head()
# Out:
#        City                         Status State     2000     2010     2020  \
# 0  Aberdeen  Micropolitan Statistical Area    SD   39,936   39,827   40,602
# 1  Aberdeen  Micropolitan Statistical Area    WA   64,175   67,194   72,797
# 2   Abilene  Metropolitan Statistical Area    TX  148,004  160,245  165,252
# 3       Ada  Micropolitan Statistical Area    OK   34,119   35,143   37,492
# 4    Adrian  Micropolitan Statistical Area    MI   91,476   98,890   99,892
#
#       2021
# 0   42,287
# 1   75,636
# 2  176,579
# 3   38,065
# 4   99,423

# %% [markdown]
# Exploring the scraped data:

# %%
# Checking number of distinct states
df2['State'].nunique()
# Out:
# 101

# %%
# Checking why there are 101 unique states
pd.set_option('max_rows', 1000)
df2['State'].value_counts()
# Out:
# TX             70
# OH             40
# NC             36
# IN             36
# CA             34
# GA             34
# PA             33
# MI             30
# FL             29
# NY             26
# AL             24
# IL             24
# TN             23
# MS             21
# MO             21
# OK             21
# WI             21
# MN             20
# AR             20
# WA             20
# KS             19
# IA             19
# KY             19
# NM             19
# LA             18
# OR             18
# CO             17
# SC             15
# PR             12
# ID             12
# SD             11
# AZ             11
# NE             11
# VA             10
# NV              9
# WV              8
# UT              8
# WY              8
# MT              7
# CT              5
# NH              5
# ND              5
# AK              4
# NJ              4
# HI              4
# ME              4
# VT              4
# MD              4
# MA              4
# ND-MN           3
# WV-OH           3
# MD-WV           2
# GA-AL           2
# MN-WI           2
# MO-IL           2
# IA-IL           2
# MO-KS           2
# NY-NJ-PA        1
# OR-WA           1
# NE-IA           1
# OR-ID           1
# MS-LA           1
# KY-IL           1
# PA-NJ-DE-MD     1
# SC-NC           1
# GA-SC           1
# RI-MA           1
# IL-MO           1
# WI-MI           1
# MD-DE           1
# IA-NE-SD        1
# IN-MI           1
# TX-AR           1
# VA-NC           1
# DC-VA-MD-WV     1
# VA-WV           1
# MA-CT           1
# TN-MS-AR        1
# TN-VA           1
# KY-IN           1
# UT-ID           1
# MA-NH           1
# WV-VA           1
# NC-SC           1
# TN-GA           1
# IL-IN-WI        1
# OH-KY-IN        1
# TN-KY           1
# DE              1
# AL-GA           1
# IN-KY           1
# PA-NJ           1
# IA-IL-MO        1
# AR-OK           1
# WV-KY-OH        1
# MI-WI           1
# WY-ID           1
# WI-MN           1
# NH-VT           1
# ID-WA           1
# OH-PA           1
# Name: State, dtype: int64

# %%
## Checking why one city would have two different states

df2.loc[df2['State'] == "ND-MN"]
# Out:
#             City                         Status  State     2000     2010  \
# 282        Fargo  Metropolitan Statistical Area  ND-MN  153,296  174,367
# 333  Grand Forks  Metropolitan Statistical Area  ND-MN  103,181   97,478
# 887     Wahpeton  Micropolitan Statistical Area  ND-MN   25,664   25,136
#
#         2020     2021
# 282  208,777  249,843
# 333   98,461  104,362
# 887   22,897   23,035

# %%
# Removing all rows that have two states
discard = ["-"]
dataframe1 = df2[~df2['State'].str.contains('|'.join(discard))]
dataframe1['State'].nunique()
# Out:
# 50

# %% [markdown]
# Cleaning the data before joining with the original dataframe:

# %%
# Creating a new column with the spelled out state names in order to join with the original dataset

states = {"AL":"Alabama", "AK":"Alaska", "AZ":"Arizona", "AR":"Arkansas", "CA":"California", "CO":"Colorado", "CT":"Connecticut", 
          "DC":"Washington DC", "DE":"Delaware", "FL":"Florida", "GA":"Georgia", "HI":"Hawaii", "ID":"Idaho", "IL":"Illinois", 
          "IN":"Indiana", "IA":"Iowa", "KS":"Kansas", "KY":"Kentucky", "LA":"Louisiana", "ME":"Maine", "MD":"Maryland",
          "MA":"Massachusetts", "MI":"Michigan", "MN":"Minnesota", "MS":"Mississippi", "MO":"Missouri", "MT":"Montana",
          "NE":"Nebraska", "NV":"Nevada", "NH":"New Hampshire", "NJ":"New Jersey", "NM":"New Mexico", "NY":"New York", 
          "NC":"North Carolina", "ND":"North Dakota", "OH":"Ohio", "OK":"Oklahoma", "OR":"Oregon", "PA":"Pennsylvania", 
          "RI":"Rhode Island", "SC":"South Carolina", "SD":"South Dakota", "TN":"Tennessee", "TX":"Texas", "UT":"Utah", "VT":"Vermont",
          "VA":"Virginia", "WA":"Washington", "WV":"West Virginia","WI":"Wisconsin", "WY":"Wyoming"}
 
dataframe1["State_Name"] = dataframe1.State.map(states)
dataframe1['State_Name'].value_counts()
# Out:
# <ipython-input-127-e96f8aabac5b>:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Texas             70
# Ohio              40
# Indiana           36
# North Carolina    36
# Georgia           34
# California        34
# Pennsylvania      33
# Michigan          30
# Florida           29
# New York          26
# Alabama           24
# Illinois          24
# Tennessee         23
# Wisconsin         21
# Mississippi       21
# Oklahoma          21
# Missouri          21
# Washington        20
# Arkansas          20
# Minnesota         20
# Kansas            19
# Iowa              19
# New Mexico        19
# Kentucky          19
# Louisiana         18
# Oregon            18
# Colorado          17
# South Carolina    15
# Idaho             12
# Arizona           11
# Nebraska          11
# South Dakota      11
# Virginia          10
# Nevada             9
# West Virginia      8
# Wyoming            8
# Utah               8
# Montana            7
# Connecticut        5
# New Hampshire      5
# North Dakota       5
# Maine              4
# Vermont            4
# Massachusetts      4
# Maryland           4
# New Jersey         4
# Alaska             4
# Hawaii             4
# Delaware           1
# Name: State_Name, dtype: int64

# %%
dataframe1.head()
# Out:
#        City                         Status State     2000     2010     2020  \
# 0  Aberdeen  Micropolitan Statistical Area    SD   39,936   39,827   40,602
# 1  Aberdeen  Micropolitan Statistical Area    WA   64,175   67,194   72,797
# 2   Abilene  Metropolitan Statistical Area    TX  148,004  160,245  165,252
# 3       Ada  Micropolitan Statistical Area    OK   34,119   35,143   37,492
# 4    Adrian  Micropolitan Statistical Area    MI   91,476   98,890   99,892
#
#       2021    State_Name
# 0   42,287  South Dakota
# 1   75,636    Washington
# 2  176,579         Texas
# 3   38,065      Oklahoma
# 4   99,423      Michigan

# %%
# Using groupby to collapse the dataframe
area_count = pd.DataFrame({'Count' : dataframe1.groupby( [ "State_Name", "Status"] ).size()}).reset_index()
area_count
# Out:
#         State_Name                         Status  Count
# 0          Alabama  Metropolitan Statistical Area     12
# 1          Alabama  Micropolitan Statistical Area     12
# 2           Alaska  Metropolitan Statistical Area      2
# 3           Alaska  Micropolitan Statistical Area      2
# 4          Arizona  Metropolitan Statistical Area      7
# 5          Arizona  Micropolitan Statistical Area      4
# 6         Arkansas  Metropolitan Statistical Area      5
# 7         Arkansas  Micropolitan Statistical Area     15
# 8       California  Metropolitan Statistical Area     26
# 9       California  Micropolitan Statistical Area      8
# 10        Colorado  Metropolitan Statistical Area      7
# 11        Colorado  Micropolitan Statistical Area     10
# 12     Connecticut  Metropolitan Statistical Area      4
# 13     Connecticut  Micropolitan Statistical Area      1
# 14        Delaware  Metropolitan Statistical Area      1
# 15         Florida  Metropolitan Statistical Area     22
# 16         Florida  Micropolitan Statistical Area      7
# 17         Georgia  Metropolitan Statistical Area     12
# 18         Georgia  Micropolitan Statistical Area     22
# 19          Hawaii  Metropolitan Statistical Area      2
# 20          Hawaii  Micropolitan Statistical Area      2
# 21           Idaho  Metropolitan Statistical Area      5
# 22           Idaho  Micropolitan Statistical Area      7
# 23        Illinois  Metropolitan Statistical Area      9
# 24        Illinois  Micropolitan Statistical Area     15
# 25         Indiana  Metropolitan Statistical Area     10
# 26         Indiana  Micropolitan Statistical Area     26
# 27            Iowa  Metropolitan Statistical Area      6
# 28            Iowa  Micropolitan Statistical Area     13
# 29          Kansas  Metropolitan Statistical Area      4
# 30          Kansas  Micropolitan Statistical Area     15
# 31        Kentucky  Metropolitan Statistical Area      4
# 32        Kentucky  Micropolitan Statistical Area     15
# 33       Louisiana  Metropolitan Statistical Area      9
# 34       Louisiana  Micropolitan Statistical Area      9
# 35           Maine  Metropolitan Statistical Area      3
# 36           Maine  Micropolitan Statistical Area      1
# 37        Maryland  Metropolitan Statistical Area      2
# 38        Maryland  Micropolitan Statistical Area      2
# 39   Massachusetts  Metropolitan Statistical Area      3
# 40   Massachusetts  Micropolitan Statistical Area      1
# 41        Michigan  Metropolitan Statistical Area     14
# 42        Michigan  Micropolitan Statistical Area     16
# 43       Minnesota  Metropolitan Statistical Area      3
# 44       Minnesota  Micropolitan Statistical Area     17
# 45     Mississippi  Metropolitan Statistical Area      3
# 46     Mississippi  Micropolitan Statistical Area     18
# 47        Missouri  Metropolitan Statistical Area      4
# 48        Missouri  Micropolitan Statistical Area     17
# 49         Montana  Metropolitan Statistical Area      3
# 50         Montana  Micropolitan Statistical Area      4
# 51        Nebraska  Metropolitan Statistical Area      2
# 52        Nebraska  Micropolitan Statistical Area      9
# 53          Nevada  Metropolitan Statistical Area      3
# 54          Nevada  Micropolitan Statistical Area      6
# 55   New Hampshire  Metropolitan Statistical Area      1
# 56   New Hampshire  Micropolitan Statistical Area      4
# 57      New Jersey  Metropolitan Statistical Area      4
# 58      New Mexico  Metropolitan Statistical Area      4
# 59      New Mexico  Micropolitan Statistical Area     15
# 60        New York  Metropolitan Statistical Area     12
# 61        New York  Micropolitan Statistical Area     14
# 62  North Carolina  Metropolitan Statistical Area     14
# 63  North Carolina  Micropolitan Statistical Area     22
# 64    North Dakota  Metropolitan Statistical Area      1
# 65    North Dakota  Micropolitan Statistical Area      4
# 66            Ohio  Metropolitan Statistical Area      9
# 67            Ohio  Micropolitan Statistical Area     31
# 68        Oklahoma  Metropolitan Statistical Area      4
# 69        Oklahoma  Micropolitan Statistical Area     17
# 70          Oregon  Metropolitan Statistical Area      7
# 71          Oregon  Micropolitan Statistical Area     11
# 72    Pennsylvania  Metropolitan Statistical Area     16
# 73    Pennsylvania  Micropolitan Statistical Area     17
# 74  South Carolina  Metropolitan Statistical Area      7
# 75  South Carolina  Micropolitan Statistical Area      8
# 76    South Dakota  Metropolitan Statistical Area      2
# 77    South Dakota  Micropolitan Statistical Area      9
# 78       Tennessee  Metropolitan Statistical Area      6
# 79       Tennessee  Micropolitan Statistical Area     17
# 80           Texas  Metropolitan Statistical Area     24
# 81           Texas  Micropolitan Statistical Area     46
# 82            Utah  Metropolitan Statistical Area      4
# 83            Utah  Micropolitan Statistical Area      4
# 84         Vermont  Metropolitan Statistical Area      1
# 85         Vermont  Micropolitan Statistical Area      3
# 86        Virginia  Metropolitan Statistical Area      7
# 87        Virginia  Micropolitan Statistical Area      3
# 88      Washington  Metropolitan Statistical Area     11
# 89      Washington  Micropolitan Statistical Area      9
# 90   West Virginia  Metropolitan Statistical Area      4
# 91   West Virginia  Micropolitan Statistical Area      4
# 92       Wisconsin  Metropolitan Statistical Area     11
# 93       Wisconsin  Micropolitan Statistical Area     10
# 94         Wyoming  Metropolitan Statistical Area      2
# 95         Wyoming  Micropolitan Statistical Area      6

# %%
# Showing Frequencies of Metropolitan and Micropolitan Areas in each state

piv_count = (area_count.pivot(index=['State_Name'],columns=["Status"], values="Count")
         .sort_index(level=[1,0]))

piv_count['Metropolitan Statistical Area'] = piv_count['Metropolitan Statistical Area'].astype('int')
piv_count['Micropolitan Statistical Area'] = piv_count['Micropolitan Statistical Area'].fillna(0)
piv_count['Micropolitan Statistical Area'] = piv_count['Micropolitan Statistical Area'].astype('int')

piv_count = piv_count.rename(columns={"State_Name" : "State Name", "Metropolitan Statistical Area" : "Metro Count",
                   "Micropolitan Statistical Area" : "Micro Count"})

piv_count = piv_count.reset_index()

piv_count.head()
# Out:
# Status  State_Name  Metro Count  Micro Count
# 0          Alabama           12           12
# 1           Alaska            2            2
# 2          Arizona            7            4
# 3         Arkansas            5           15
# 4       California           26            8

# %% [markdown]
# Feature Engineering:

# %%
# Calculating the % metropolitan and micropolitan cities per state

piv_count['% Metro'] = (piv_count['Metro Count'] / (piv_count['Metro Count'] + piv_count['Micro Count'])) *100 
piv_count['% Micro'] = (piv_count['Micro Count'] / (piv_count['Metro Count'] + piv_count['Micro Count'])) *100 

piv_count['% Metro'] = piv_count['% Metro'].round(decimals=2)
piv_count['% Micro'] = piv_count['% Micro'].round(decimals=2)

piv_count.head()
# Out:
# Status  State_Name  Metro Count  Micro Count  % Metro  % Micro
# 0          Alabama           12           12    50.00    50.00
# 1           Alaska            2            2    50.00    50.00
# 2          Arizona            7            4    63.64    36.36
# 3         Arkansas            5           15    25.00    75.00
# 4       California           26            8    76.47    23.53

# %%
# Checking the original data
acs_df.head()
# Out:
#    Total Households  Less than $10k  $200k+  district number        State  \
# 0            289474           14153   19390               10     Michigan
# 1            299804           23793   10899                4  Mississippi
# 2            278057           27728   19574               14     Michigan
# 3            306685           19036   12208                1     Michigan
# 4            285554           26481   12412                3  Mississippi
#
#    % of households over $200k  % of households less than $10k
# 0                    6.698356                        4.889213
# 1                    3.635375                        7.936185
# 2                    7.039564                        9.972056
# 3                    3.980632                        6.207020
# 4                    4.346638                        9.273552

# %%
# Performing a left join on the original data
data2 = (acs_df.groupby(['State'], as_index=False).mean()
            .groupby('State')['% of households over $200k', '% of households less than $10k'].mean().reset_index())

data2 = data2.rename(columns={"% of households over $200k" : "% over 200k",
                   "% of households less than $10k" : "% under 10k"})

data2['% over 200k'] = data2['% over 200k'].round(decimals=2)
data2['% under 10k'] = data2['% under 10k'].round(decimals=2)

data2.head()
# Out:
# <ipython-input-133-697965ebd79d>:2: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#         State  % over 200k  % under 10k
# 0     Alabama         5.10         7.80
# 1      Alaska        10.21         5.39
# 2     Arizona         7.86         5.76
# 3    Arkansas         4.60         7.67
# 4  California        14.92         5.34

# %%
final_df = data2.set_index('State').join(piv_count.set_index('State_Name'), on='State')
final_df = final_df.reset_index()
final_df.head()
# Out:
#         State  % over 200k  % under 10k  Metro Count  Micro Count  % Metro  \
# 0     Alabama         5.10         7.80         12.0         12.0    50.00
# 1      Alaska        10.21         5.39          2.0          2.0    50.00
# 2     Arizona         7.86         5.76          7.0          4.0    63.64
# 3    Arkansas         4.60         7.67          5.0         15.0    25.00
# 4  California        14.92         5.34         26.0          8.0    76.47
#
#    % Micro
# 0    50.00
# 1    50.00
# 2    36.36
# 3    75.00
# 4    23.53

# %%
# Removing districts that are not in the scraped data

discard = ["Puerto", "Rhode", "Columbia"]
final_df = final_df[~final_df['State'].str.contains('|'.join(discard))]
final_df['State'].nunique()
# Out:
# 49

# %%
# % of metropolitan cities vs households that cost over 200k per state

fig = px.scatter(final_df, x = '% over 200k', y = '% Metro')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="bca5a401-8cb8-4f23-ae23-264c1f201c60" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bca5a401-8cb8-4f23-ae23-264c1f201c60")) {                    Plotly.newPlot(                        "bca5a401-8cb8-4f23-ae23-264c1f201c60",                        [{"hovertemplate":"% over 200k=%{x}<br>% Metro=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[5.1,10.21,7.86,4.6,14.92,11.93,14.66,8.35,7.69,8.22,13.26,6.54,9.95,5.62,6.17,6.3,5.06,5.57,6.62,15.08,17.12,6.67,9.9,3.51,6.37,6.86,6.59,7.25,11.33,16.84,5.76,13.04,7.29,6.02,6.44,4.9,8.98,8.64,5.84,5.69,6.31,8.39,9.92,8.72,13.33,13.67,4.32,6.5,5.84],"xaxis":"x","y":[50.0,50.0,63.64,25.0,76.47,41.18,80.0,100.0,75.86,35.29,50.0,41.67,37.5,27.78,31.58,21.05,21.05,50.0,75.0,50.0,75.0,46.67,15.0,14.29,19.05,42.86,18.18,33.33,20.0,100.0,21.05,46.15,38.89,20.0,22.5,19.05,38.89,48.48,46.67,18.18,26.09,34.29,50.0,25.0,70.0,55.0,50.0,52.38,25.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#e ...

# %%
# % of metropolitan cities vs households that cost under 10k per state

fig1 = px.scatter(final_df, x = '% under 10k', y = '% Metro')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fe25e6a4-537e-44dc-b9b7-4facae42650b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe25e6a4-537e-44dc-b9b7-4facae42650b")) {                    Plotly.newPlot(                        "fe25e6a4-537e-44dc-b9b7-4facae42650b",                        [{"hovertemplate":"% over 200k=%{x}<br>% Metro=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[5.1,10.21,7.86,4.6,14.92,11.93,14.66,8.35,7.69,8.22,13.26,6.54,9.95,5.62,6.17,6.3,5.06,5.57,6.62,15.08,17.12,6.67,9.9,3.51,6.37,6.86,6.59,7.25,11.33,16.84,5.76,13.04,7.29,6.02,6.44,4.9,8.98,8.64,5.84,5.69,6.31,8.39,9.92,8.72,13.33,13.67,4.32,6.5,5.84],"xaxis":"x","y":[50.0,50.0,63.64,25.0,76.47,41.18,80.0,100.0,75.86,35.29,50.0,41.67,37.5,27.78,31.58,21.05,21.05,50.0,75.0,50.0,75.0,46.67,15.0,14.29,19.05,42.86,18.18,33.33,20.0,100.0,21.05,46.15,38.89,20.0,22.5,19.05,38.89,48.48,46.67,18.18,26.09,34.29,50.0,25.0,70.0,55.0,50.0,52.38,25.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#e ...
